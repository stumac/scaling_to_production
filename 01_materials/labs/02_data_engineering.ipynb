# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# $PEAK: possibly delisted; No timezone found
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 0.7837240695953369 seconds.
# Csv file size 14.032608999999999 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# /tmp/ipykernel_429934/676544213.py:1: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
#   import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 0.3457329273223877 seconds.
# Parquet file size 5.555129 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
print(PRICE_DATA)
dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# ../../05_src/data/prices/
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/backends.py:141, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     140 try:
# --> 141     return func(*args, **kwargs)
#     142 except Exception as e:
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/dataframe/io/parquet/core.py:529, in read_parquet(path, columns, filters, categories, index, storage_options, engine, use_nullable_dtypes, dtype_backend, calculate_divisions, ignore_metadata_file, metadata_task_size, split_row_groups, blocksize, aggregate_files, parquet_file_extension, filesystem, **kwargs)
#     527     blocksize = None
# --> 529 read_metadata_result = engine.read_metadata(
#     530     fs,
#     531     paths,
#     532     categories=categories,
#     533     index=index,
#     534     use_nullable_dtypes=use_nullable_dtypes,
#     535     dtype_backend=dtype_backend,
#     536     gather_statistics=calculate_divisions,
#     537     filters=filters,
#     538     split_row_groups=split_row_groups,
#     539     blocksize=blocksize,
#     540     aggregate_files=aggregate_files,
#     541     ignore_metadata_file=ignore_metadata_file,
#     542     metadata_task_size=metadata_task_size,
#     543     parquet_file_extension=parquet_file_extension,
#     544     dataset=dataset_options,
#     545     read=read_options,
#     546     **other_options,
#     547 )
#     549 # In the future, we may want to give the engine the
#     550 # option to return a dedicated element for `common_kwargs`.
#     551 # However, to avoid breaking the API, we just embed this
#     552 # data in the first element of `parts` for now.
#     553 # The logic below is inteded to handle backward and forward
#     554 # compatibility with a user-defined engine.
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/dataframe/io/parquet/arrow.py:545, in ArrowDatasetEngine.read_metadata(cls, fs, paths, categories, index, use_nullable_dtypes, dtype_backend, gather_statistics, filters, split_row_groups, blocksize, aggregate_files, ignore_metadata_file, metadata_task_size, parquet_file_extension, **kwargs)
#     544 # Stage 1: Collect general dataset information
# --> 545 dataset_info = cls._collect_dataset_info(
#     546     paths,
#     547     fs,
#     548     categories,
#     549     index,
#     550     gather_statistics,
#     551     filters,
#     552     split_row_groups,
#     553     blocksize,
#     554     aggregate_files,
#     555     ignore_metadata_file,
#     556     metadata_task_size,
#     557     parquet_file_extension,
#     558     kwargs,
#     559 )
#     561 # Stage 2: Generate output `meta`
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/dataframe/io/parquet/arrow.py:1060, in ArrowDatasetEngine._collect_dataset_info(cls, paths, fs, categories, index, gather_statistics, filters, split_row_groups, blocksize, aggregate_files, ignore_metadata_file, metadata_task_size, parquet_file_extension, kwargs)
#    1059 if ds is None:
# -> 1060     ds = pa_ds.dataset(
#    1061         paths,
#    1062         filesystem=_wrapped_fs(fs),
#    1063         **_processed_dataset_kwargs,
#    1064     )
#    1066 # Get file_frag sample and extract physical_schema
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/pyarrow/dataset.py:797, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     796 if all(_is_path_like(elem) or isinstance(elem, FileInfo) for elem in source):
# --> 797     return _filesystem_dataset(source, **kwargs)
#     798 elif all(isinstance(elem, Dataset) for elem in source):
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/pyarrow/dataset.py:474, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     473     else:
# --> 474         fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     475 else:
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/pyarrow/dataset.py:384, in _ensure_multiple_sources(paths, filesystem)
#     383 elif file_type == FileType.Directory:
# --> 384     raise IsADirectoryError(
#     385         'Path {} points to a directory, but only file paths are '
#     386         'supported. To construct a nested or union dataset pass '
#     387         'a list of dataset objects instead.'.format(info.path)
#     388     )
#     389 else:
#
# IsADirectoryError: Path /home/stumac/code/uoft_dsi/scaling_to_production/01_materials/labs/../../05_src/data/prices/A/A_2000.parquet points to a directory, but only file paths are supported. To construct a nested or union dataset pass a list of dataset objects instead.
#
# The above exception was the direct cause of the following exception:
#
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[24], line 5
#       3 parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
#       4 print(PRICE_DATA)
# ----> 5 dd_px = dd.read_parquet(parquet_files).set_index("ticker")
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/backends.py:143, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     141     return func(*args, **kwargs)
#     142 except Exception as e:
# --> 143     raise type(e)(
#     144         f"An error occurred while calling the {funcname(func)} "
#     145         f"method registered to the {self.backend} backend.\n"
#     146         f"Original Message: {e}"
#     147     ) from e
#
# IsADirectoryError: An error occurred while calling the read_parquet method registered to the pandas backend.
# Original Message: Path /home/stumac/code/uoft_dsi/scaling_to_production/01_materials/labs/../../05_src/data/prices/A/A_2000.parquet points to a directory, but only file paths are supported. To construct a nested or union dataset pass a list of dataset objects instead.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# /tmp/ipykernel_393119/3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=49
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int64
# ABNB                                         ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.995823   35.126720   34.760205
# A      2013-12-03 00:00:00-05:00   34.635854   34.799480   34.400236
# A      2013-12-04 00:00:00-05:00   34.583484   35.231436   34.504947
# A      2013-12-05 00:00:00-05:00   34.917279   35.211801   34.766746
# A      2013-12-06 00:00:00-05:00   35.185626   35.951381   35.185626
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  128.551783  129.027053  127.274475
# YUM    2024-01-26 00:00:00-05:00  128.640891  129.403315  127.403198
# YUM    2024-01-29 00:00:00-05:00  127.828973  129.264694  127.026935
# YUM    2024-01-30 00:00:00-05:00  129.076565  129.928098  128.304245
# YUM    2024-01-31 00:00:00-05:00  130.155828  130.680609  127.987387
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.825653  2039962        0.0           0.0  2013          NaN
# A        34.642399  3462706        0.0           0.0  2013    34.825653
# A        35.067810  3377288        0.0           0.0  2013    34.642399
# A        35.015453  2530939        0.0           0.0  2013    35.067810
# A        35.885933  4268513        0.0           0.0  2013    35.015453
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.937943  1871700        0.0           0.0  2024   128.165619
# YUM     127.819061  1157000        0.0           0.0  2024   128.937943
# YUM     129.264694  1482100        0.0           0.0  2024   127.819061
# YUM     129.334000  1421500        0.0           0.0  2024   129.264694
# YUM     128.215134  2154200        0.0           0.0  2024   129.334000
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012280                1
# A      -0.001493                0
# A       0.024860                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-06-29 15:20:39,862, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-06-29 15:20:39,862, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-06-29 15:20:39,863, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-06-29 15:20:39,863, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-06-29 15:20:39,867, data_manager.py, 58, INFO, Processing all tickers
# 2024-06-29 15:20:39,867, data_manager.py, 58, INFO, Processing all tickers
# 2024-06-29 15:20:39,869, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-06-29 15:20:39,869, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-06-29 15:20:39,869, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:39,869, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:20:40,166, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03   40.159908   40.342808   39.323788   39.454430   19.920652
# 2000-01-04   38.827339   39.637333   37.886707   37.886707   19.129105
# 2000-01-05   38.095737   40.238293   38.095737   38.984116   19.683187
# 2000-01-06   39.428303   42.851170   39.428303   42.119564   21.266285
# 2000-01-07   42.276337   43.399876   41.779892   42.955685   21.688435
# ...                ...         ...         ...         ...         ...
# 2024-06-24  102.180000  103.500000  101.680000  102.989998  102.989998
# 2024-06-25  102.879997  103.180000  101.290001  102.050003  102.050003
# 2024-06-26  101.620003  101.800003  100.570000  101.449997  101.449997
# 2024-06-27  101.959999  104.040001  101.639999  103.169998  103.169998
# 2024-06-28  103.010002  103.970001  101.660004  102.190002  102.190002
#
#              Volume
# Date
# 2000-01-03  2599386
# 2000-01-04  3245705
# 2000-01-05  4424482
# 2000-01-06  7147057
# 2000-01-07  4905035
# ...             ...
# 2024-06-24  2948000
# 2024-06-25  5164200
# 2024-06-26  2356100
# 2024-06-27  4338300
# 2024-06-28  6195000
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:40,166, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03   40.159908   40.342808   39.323788   39.454430   19.920652
# 2000-01-04   38.827339   39.637333   37.886707   37.886707   19.129105
# 2000-01-05   38.095737   40.238293   38.095737   38.984116   19.683187
# 2000-01-06   39.428303   42.851170   39.428303   42.119564   21.266285
# 2000-01-07   42.276337   43.399876   41.779892   42.955685   21.688435
# ...                ...         ...         ...         ...         ...
# 2024-06-24  102.180000  103.500000  101.680000  102.989998  102.989998
# 2024-06-25  102.879997  103.180000  101.290001  102.050003  102.050003
# 2024-06-26  101.620003  101.800003  100.570000  101.449997  101.449997
# 2024-06-27  101.959999  104.040001  101.639999  103.169998  103.169998
# 2024-06-28  103.010002  103.970001  101.660004  102.190002  102.190002
#
#              Volume
# Date
# 2000-01-03  2599386
# 2000-01-04  3245705
# 2000-01-05  4424482
# 2000-01-06  7147057
# 2000-01-07  4905035
# ...             ...
# 2024-06-24  2948000
# 2024-06-25  5164200
# 2024-06-26  2356100
# 2024-06-27  4338300
# 2024-06-28  6195000
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:40,167, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-06-29 15:20:40,167, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-06-29 15:20:40,929, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-06-29 15:20:40,929, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-06-29 15:20:40,930, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:40,930, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:20:41,161, data_manager.py, 110, INFO, stock data:                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2000-01-03   3.635417   3.645833   3.572917   3.614583   2.330968   113400
# 2000-01-04   3.604167   3.666667   3.562500   3.562500   2.297381   164400
# 2000-01-05   3.583333   3.583333   3.489583   3.552083   2.290662   188400
# 2000-01-06   3.541667   3.552083   3.500000   3.500000   2.257075   161400
# 2000-01-07   3.520833   3.645833   3.520833   3.645833   2.351120   106200
# ...               ...        ...        ...        ...        ...      ...
# 2024-06-24  84.330002  85.589996  83.919998  84.430000  84.430000   928600
# 2024-06-25  83.930000  84.220001  82.019997  82.930000  82.930000   922500
# 2024-06-26  82.500000  82.559998  81.769997  82.379997  82.379997   876900
# 2024-06-27  81.690002  82.669998  81.669998  82.019997  82.019997   868500
# 2024-06-28  82.139999  83.370003  81.260002  81.779999  81.779999  1378400
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:41,161, data_manager.py, 110, INFO, stock data:                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2000-01-03   3.635417   3.645833   3.572917   3.614583   2.330968   113400
# 2000-01-04   3.604167   3.666667   3.562500   3.562500   2.297381   164400
# 2000-01-05   3.583333   3.583333   3.489583   3.552083   2.290662   188400
# 2000-01-06   3.541667   3.552083   3.500000   3.500000   2.257075   161400
# 2000-01-07   3.520833   3.645833   3.520833   3.645833   2.351120   106200
# ...               ...        ...        ...        ...        ...      ...
# 2024-06-24  84.330002  85.589996  83.919998  84.430000  84.430000   928600
# 2024-06-25  83.930000  84.220001  82.019997  82.930000  82.930000   922500
# 2024-06-26  82.500000  82.559998  81.769997  82.379997  82.379997   876900
# 2024-06-27  81.690002  82.669998  81.669998  82.019997  82.019997   868500
# 2024-06-28  82.139999  83.370003  81.260002  81.779999  81.779999  1378400
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:41,162, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-06-29 15:20:41,162, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-06-29 15:20:41,925, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-06-29 15:20:41,925, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-06-29 15:20:41,925, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:41,925, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:20:42,186, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03   15.823756   16.160433   15.599306   15.711531    8.371425
# 2000-01-04   15.459024   15.599306   15.150405   15.262630    8.132235
# 2000-01-05   15.066236   15.402911   15.066236   15.234574    8.117288
# 2000-01-06   15.262630   15.823756   15.178461   15.767643    8.401319
# 2000-01-07   15.487080   16.272657   15.487080   15.935981    8.491013
# ...                ...         ...         ...         ...         ...
# 2024-06-24  106.290001  106.290001  104.940002  105.300003  105.300003
# 2024-06-25  105.400002  105.980003  104.820000  105.489998  105.489998
# 2024-06-26  105.089996  105.650002  104.320000  104.879997  104.879997
# 2024-06-27  105.250000  105.320000  103.919998  104.650002  104.650002
# 2024-06-28  104.699997  105.160004  103.529999  103.910004  103.910004
#
#               Volume
# Date
# 2000-01-03  10635087
# 2000-01-04  10734887
# 2000-01-05  11722632
# 2000-01-06  17479583
# 2000-01-07  15756040
# ...              ...
# 2024-06-24   5201300
# 2024-06-25   4722600
# 2024-06-26   5406600
# 2024-06-27   4137600
# 2024-06-28   8283300
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:42,186, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03   15.823756   16.160433   15.599306   15.711531    8.371425
# 2000-01-04   15.459024   15.599306   15.150405   15.262630    8.132235
# 2000-01-05   15.066236   15.402911   15.066236   15.234574    8.117288
# 2000-01-06   15.262630   15.823756   15.178461   15.767643    8.401319
# 2000-01-07   15.487080   16.272657   15.487080   15.935981    8.491013
# ...                ...         ...         ...         ...         ...
# 2024-06-24  106.290001  106.290001  104.940002  105.300003  105.300003
# 2024-06-25  105.400002  105.980003  104.820000  105.489998  105.489998
# 2024-06-26  105.089996  105.650002  104.320000  104.879997  104.879997
# 2024-06-27  105.250000  105.320000  103.919998  104.650002  104.650002
# 2024-06-28  104.699997  105.160004  103.529999  103.910004  103.910004
#
#               Volume
# Date
# 2000-01-03  10635087
# 2000-01-04  10734887
# 2000-01-05  11722632
# 2000-01-06  17479583
# 2000-01-07  15756040
# ...              ...
# 2024-06-24   5201300
# 2024-06-25   4722600
# 2024-06-26   5406600
# 2024-06-27   4137600
# 2024-06-28   8283300
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:42,187, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-06-29 15:20:42,187, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-06-29 15:20:42,995, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-06-29 15:20:42,995, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-06-29 15:20:42,996, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:42,996, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:20:43,123, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-01-02   34.919998   35.400002   34.099998   35.119999   22.002174
# 2013-01-03   35.000000   35.000000   34.160000   34.830002   21.820498
# 2013-01-04   34.619999   34.889999   34.250000   34.389999   21.544840
# 2013-01-07   34.150002   35.450001   34.150002   34.459999   21.588697
# 2013-01-08   34.290001   34.639999   33.360001   33.709999   21.118835
# ...                ...         ...         ...         ...         ...
# 2024-06-24  171.130005  173.410004  170.699997  172.740005  172.740005
# 2024-06-25  172.100006  173.410004  170.619995  170.750000  170.750000
# 2024-06-26  170.289993  172.350006  170.149994  171.149994  171.149994
# 2024-06-27  171.289993  171.559998  167.750000  168.990005  168.990005
# 2024-06-28  169.990005  171.820007  169.050003  171.520004  171.520004
#
#               Volume
# Date
# 2013-01-02  13767900
# 2013-01-03  16739300
# 2013-01-04  21372100
# 2013-01-07  17897100
# 2013-01-08  17863300
# ...              ...
# 2024-06-24   6249900
# 2024-06-25   5712700
# 2024-06-26   5576100
# 2024-06-27   5382000
# 2024-06-28  24463400
#
# [2892 rows x 6 columns]
# 2024-06-29 15:20:43,123, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-01-02   34.919998   35.400002   34.099998   35.119999   22.002174
# 2013-01-03   35.000000   35.000000   34.160000   34.830002   21.820498
# 2013-01-04   34.619999   34.889999   34.250000   34.389999   21.544840
# 2013-01-07   34.150002   35.450001   34.150002   34.459999   21.588697
# 2013-01-08   34.290001   34.639999   33.360001   33.709999   21.118835
# ...                ...         ...         ...         ...         ...
# 2024-06-24  171.130005  173.410004  170.699997  172.740005  172.740005
# 2024-06-25  172.100006  173.410004  170.619995  170.750000  170.750000
# 2024-06-26  170.289993  172.350006  170.149994  171.149994  171.149994
# 2024-06-27  171.289993  171.559998  167.750000  168.990005  168.990005
# 2024-06-28  169.990005  171.820007  169.050003  171.520004  171.520004
#
#               Volume
# Date
# 2013-01-02  13767900
# 2013-01-03  16739300
# 2013-01-04  21372100
# 2013-01-07  17897100
# 2013-01-08  17863300
# ...              ...
# 2024-06-24   6249900
# 2024-06-25   5712700
# 2024-06-26   5576100
# 2024-06-27   5382000
# 2024-06-28  24463400
#
# [2892 rows x 6 columns]
# 2024-06-29 15:20:43,124, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-06-29 15:20:43,124, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-06-29 15:20:43,557, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-06-29 15:20:43,557, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-06-29 15:20:43,558, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:43,558, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06
# 2024-06-27  18.790001  19.170000  18.730000  19.09000  19.090000   4599700
# 2024-06-28  19.209999  19.209999  17.350000  17.57000  17.570000  28439000
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:46,570, data_manager.py, 110, INFO, stock data:                  Open       High        Low     Close  Adj Close    Volume
# Date
# 2000-01-03  37.375000  37.375000  35.625000  36.25000  25.357718   1334400
# 2000-01-04  35.937500  35.968750  34.625000  34.81250  24.352144   1484800
# 2000-01-05  34.843750  35.375000  34.250000  35.18750  24.614468   1569800
# 2000-01-06  35.312500  35.812500  35.000000  35.46875  24.811214   1708400
# 2000-01-07  35.343750  36.156250  35.093750  36.15625  25.292135   1449400
# ...               ...        ...        ...       ...        ...       ...
# 2024-06-24  18.570000  19.139999  18.530001  18.99000  18.990000   4883000
# 2024-06-25  19.150000  19.240000  18.830000  18.90000  18.900000   3975800
# 2024-06-26  18.750000  19.309999  18.740000  18.91000  18.910000   8909500
# 2024-06-27  18.790001  19.170000  18.730000  19.09000  19.090000   4599700
# 2024-06-28  19.209999  19.209999  17.350000  17.57000  17.570000  28439000
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:46,570, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-06-29 15:20:46,570, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-06-29 15:20:47,410, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-06-29 15:20:47,410, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-06-29 15:20:47,412, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:47,412, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:20:47,647, data_manager.py, 110, INFO, stock data:                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2000-01-03  11.734375  11.781250  11.078125  11.187500   6.878608  2388800
# 2000-01-04  10.812500  11.281250  10.812500  10.890625   6.696078  2716400
# 2000-01-05  10.906250  11.046875  10.796875  10.828125   6.657649  1354800
# 2000-01-06  10.781250  11.109375  10.718750  11.046875   6.792149  2027200
# 2000-01-07  11.031250  11.281250  10.968750  11.265625   6.926642  2262000
# ...               ...        ...        ...        ...        ...      ...
# 2024-06-24  89.500000  91.150002  89.070000  90.430000  90.430000  2108500
# 2024-06-25  90.430000  90.930000  89.790001  90.010002  90.010002  2212000
# 2024-06-26  89.370003  89.699997  88.239998  89.220001  89.220001  2686200
# 2024-06-27  89.349998  89.360001  88.709999  89.160004  89.160004  1993800
# 2024-06-28  89.349998  90.209999  88.830002  89.309998  89.309998  3455200
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:47,647, data_manager.py, 110, INFO, stock data:                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2000-01-03  11.734375  11.781250  11.078125  11.187500   6.878608  2388800
# 2000-01-04  10.812500  11.281250  10.812500  10.890625   6.696078  2716400
# 2000-01-05  10.906250  11.046875  10.796875  10.828125   6.657649  1354800
# 2000-01-06  10.781250  11.109375  10.718750  11.046875   6.792149  2027200
# 2000-01-07  11.031250  11.281250  10.968750  11.265625   6.926642  2262000
# ...               ...        ...        ...        ...        ...      ...
# 2024-06-24  89.500000  91.150002  89.070000  90.430000  90.430000  2108500
# 2024-06-25  90.430000  90.930000  89.790001  90.010002  90.010002  2212000
# 2024-06-26  89.370003  89.699997  88.239998  89.220001  89.220001  2686200
# 2024-06-27  89.349998  89.360001  88.709999  89.160004  89.160004  1993800
# 2024-06-28  89.349998  90.209999  88.830002  89.309998  89.309998  3455200
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:47,648, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-06-29 15:20:47,648, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-06-29 15:20:48,443, data_manager.py, 73, INFO, Processing ticker A
# 2024-06-29 15:20:48,443, data_manager.py, 73, INFO, Processing ticker A
# 2024-06-29 15:20:48,444, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:48,444, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:20:48,656, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03   56.330471   56.464592   48.193848   51.502148   43.612999
# 2000-01-04   48.730328   49.266811   46.316166   47.567955   40.281460
# 2000-01-05   47.389126   47.567955   43.141991   44.617310   37.782795
# 2000-01-06   44.080830   44.349072   41.577251   42.918453   36.344173
# 2000-01-07   42.247852   47.165592   42.203148   46.494991   39.372856
# ...                ...         ...         ...         ...         ...
# 2024-06-24  135.300003  137.710007  134.339996  135.080002  135.080002
# 2024-06-25  135.000000  136.009995  134.289993  134.690002  134.690002
# 2024-06-26  133.990005  135.210007  132.759995  133.089996  133.089996
# 2024-06-27  132.199997  132.990005  130.580002  130.800003  130.800003
# 2024-06-28  131.660004  133.039993  128.389999  129.630005  129.630005
#
#              Volume
# Date
# 2000-01-03  4674353
# 2000-01-04  4765083
# 2000-01-05  5758642
# 2000-01-06  2534434
# 2000-01-07  2819626
# ...             ...
# 2024-06-24  3339500
# 2024-06-25  2310800
# 2024-06-26  1836800
# 2024-06-27  1898000
# 2024-06-28  9817600
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:48,656, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03   56.330471   56.464592   48.193848   51.502148   43.612999
# 2000-01-04   48.730328   49.266811   46.316166   47.567955   40.281460
# 2000-01-05   47.389126   47.567955   43.141991   44.617310   37.782795
# 2000-01-06   44.080830   44.349072   41.577251   42.918453   36.344173
# 2000-01-07   42.247852   47.165592   42.203148   46.494991   39.372856
# ...                ...         ...         ...         ...         ...
# 2024-06-24  135.300003  137.710007  134.339996  135.080002  135.080002
# 2024-06-25  135.000000  136.009995  134.289993  134.690002  134.690002
# 2024-06-26  133.990005  135.210007  132.759995  133.089996  133.089996
# 2024-06-27  132.199997  132.990005  130.580002  130.800003  130.800003
#
# [892 rows x 6 columns]
# 2024-06-29 15:20:50,659, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-06-29 15:20:50,659, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-06-29 15:20:50,816, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-06-29 15:20:50,816, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-06-29 15:20:50,817, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:50,817, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:20:50,968, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03  344.187500  345.500000  311.000000  321.250000  321.250000
# 2000-01-04  320.000000  321.500000  300.000000  300.000000  300.000000
# 2000-01-05  282.500000  299.625000  262.000000  283.500000  283.500000
# 2000-01-06  272.000000  278.125000  235.250000  236.125000  236.125000
# 2000-01-07  248.375000  254.500000  238.000000  248.375000  248.375000
# ...                ...         ...         ...         ...         ...
# 2024-06-24   89.029999   89.980003   88.650002   88.739998   88.739998
# 2024-06-25   88.739998   88.849998   87.889999   88.250000   88.250000
# 2024-06-26   88.000000   89.139999   87.830002   88.430000   88.430000
# 2024-06-27   88.440002   89.970001   88.120003   89.940002   89.940002
# 2024-06-28   90.000000   90.470001   89.510002   90.080002   90.080002
#
#              Volume
# Date
# 2000-01-03   285600
# 2000-01-04   215900
# 2000-01-05  1183500
# 2000-01-06   797500
# 2000-01-07   729100
# ...             ...
# 2024-06-24  1580700
# 2024-06-25  1165700
# 2024-06-26   937900
# 2024-06-27  1382400
# 2024-06-28  2069700
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:50,968, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03  344.187500  345.500000  311.000000  321.250000  321.250000
# 2000-01-04  320.000000  321.500000  300.000000  300.000000  300.000000
# 2000-01-05  282.500000  299.625000  262.000000  283.500000  283.500000
# 2000-01-06  272.000000  278.125000  235.250000  236.125000  236.125000
# 2000-01-07  248.375000  254.500000  238.000000  248.375000  248.375000
# ...                ...         ...         ...         ...         ...
# 2024-06-24   89.029999   89.980003   88.650002   88.739998   88.739998
# 2024-06-25   88.739998   88.849998   87.889999   88.250000   88.250000
# 2024-06-26   88.000000   89.139999   87.830002   88.430000   88.430000
# 2024-06-27   88.440002   89.970001   88.120003   89.940002   89.940002
# 2024-06-28   90.000000   90.470001   89.510002   90.080002   90.080002
#
#              Volume
# Date
# 2000-01-03   285600
# 2000-01-04   215900
# 2000-01-05  1183500
# 2000-01-06   797500
# 2000-01-07   729100
# ...             ...
# 2024-06-24  1580700
# 2024-06-25  1165700
# 2024-06-26   937900
# 2024-06-27  1382400
# 2024-06-28  2069700
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:50,968, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-06-29 15:20:50,968, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-06-29 15:20:51,761, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-06-29 15:20:51,761, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-06-29 15:20:51,762, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:51,762, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:20:51,982, data_manager.py, 110, INFO, stock data:                  Open        High        Low       Close   Adj Close   Volume
# Date
# 2000-01-03   9.656250    9.656250   9.000000    9.000000    6.068265   134000
# 2000-01-04   8.875000    9.281250   8.875000    9.000000    6.068265    68200
# 2000-01-05   9.000000    9.250000   9.000000    9.156250    6.173620    70000
# 2000-01-06   9.093750    9.500000   9.031250    9.468750    6.384321    78600
# 2000-01-07   9.437500    9.468750   9.250000    9.312500    6.278967    71800
# ...               ...         ...        ...         ...         ...      ...
# 2024-06-24  93.550003   96.529999  93.190002   96.400002   96.400002  3280600
# 2024-06-25  95.199997   96.110001  92.610001   92.769997   92.769997  3220900
# 2024-06-26  95.519997  100.629997  95.029999  100.279999  100.279999  4847600
# 2024-06-27  98.480003   99.099998  94.879997   96.269997   96.269997  4049900
# 2024-06-28  96.500000   96.599998  93.540001   95.519997   95.519997  4486900
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:51,982, data_manager.py, 110, INFO, stock data:                  Open        High        Low       Close   Adj Close   Volume
# Date
# 2000-01-03   9.656250    9.656250   9.000000    9.000000    6.068265   134000
# 2000-01-04   8.875000    9.281250   8.875000    9.000000    6.068265    68200
# 2000-01-05   9.000000    9.250000   9.000000    9.156250    6.173620    70000
# 2000-01-06   9.093750    9.500000   9.031250    9.468750    6.384321    78600
# 2000-01-07   9.437500    9.468750   9.250000    9.312500    6.278967    71800
# ...               ...         ...        ...         ...         ...      ...
# 2024-06-24  93.550003   96.529999  93.190002   96.400002   96.400002  3280600
# 2024-06-25  95.199997   96.110001  92.610001   92.769997   92.769997  3220900
# 2024-06-26  95.519997  100.629997  95.029999  100.279999  100.279999  4847600
# 2024-06-27  98.480003   99.099998  94.879997   96.269997   96.269997  4049900
# 2024-06-28  96.500000   96.599998  93.540001   95.519997   95.519997  4486900
#
# [6161 rows x 6 columns]
# 2024-06-29 15:20:51,983, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-06-29 15:20:51,983, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-06-29 15:20:52,795, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-06-29 15:20:52,795, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-06-29 15:20:52,797, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-06-29
# 2024-06-29 15:20:52,797, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:28:25,458, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03    6.930715    6.930715    6.661125    6.706057    4.657410
# 2000-01-04    6.649892    6.739756    6.470165    6.571262    4.563793
# 2000-01-05    6.604960    6.638659    6.571262    6.604960    4.587199
# 2000-01-06    6.560029    6.616193    6.537563    6.548796    4.548193
# 2000-01-07    6.548796    6.560029    6.357836    6.402768    4.446773
# ...                ...         ...         ...         ...         ...
# 2024-06-24  134.429993  135.100006  133.330002  133.990005  133.990005
# 2024-06-25  134.000000  134.000000  131.669998  132.330002  132.330002
# 2024-06-26  131.850006  133.000000  131.270004  131.960007  131.960007
# 2024-06-27  132.080002  132.809998  131.649994  132.610001  132.610001
# 2024-06-28  132.509995  132.990005  131.720001  132.460007  132.460007
#
#              Volume
# Date
# 2000-01-03  3033493
# 2000-01-04  3315031
# 2000-01-05  4642602
# 2000-01-06  3947658
# 2000-01-07  6063647
# ...             ...
# 2024-06-24  2477100
# 2024-06-25  2367100
# 2024-06-26  1392500
# 2024-06-27  1355500
# 2024-06-28  5819000
#
# [6161 rows x 6 columns]
# 2024-06-29 15:28:25,458, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03    6.930715    6.930715    6.661125    6.706057    4.657410
# 2000-01-04    6.649892    6.739756    6.470165    6.571262    4.563793
# 2000-01-05    6.604960    6.638659    6.571262    6.604960    4.587199
# 2000-01-06    6.560029    6.616193    6.537563    6.548796    4.548193
# 2000-01-07    6.548796    6.560029    6.357836    6.402768    4.446773
# ...                ...         ...         ...         ...         ...
# 2024-06-24  134.429993  135.100006  133.330002  133.990005  133.990005
# 2024-06-25  134.000000  134.000000  131.669998  132.330002  132.330002
# 2024-06-26  131.850006  133.000000  131.270004  131.960007  131.960007
# 2024-06-27  132.080002  132.809998  131.649994  132.610001  132.610001
# 2024-06-28  132.509995  132.990005  131.720001  132.460007  132.460007
#
#              Volume
# Date
# 2000-01-03  3033493
# 2000-01-04  3315031
# 2000-01-05  4642602
# 2000-01-06  3947658
# 2000-01-07  6063647
# ...             ...
# 2024-06-24  2477100
# 2024-06-25  2367100
# 2024-06-26  1392500
# 2024-06-27  1355500
# 2024-06-28  5819000
#
# [6161 rows x 6 columns]
# 2024-06-29 15:28:25,458, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-06-29 15:28:25,458, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-06-29 15:28:26,317, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-06-29 15:28:26,317, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-06-29 15:28:26,318, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-06-29
# 2024-06-29 15:28:26,318, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06
# 2024-06-26  41.680000  41.880001  41.430000  41.849998  41.849998   778800
# 2024-06-27  41.830002  42.119999  41.410000  42.060001  42.060001   875500
# 2024-06-28  42.560001  43.470001  42.279999  43.369999  43.369999  1867800
#
# [6161 rows x 6 columns]
# 2024-06-29 15:28:28,417, data_manager.py, 110, INFO, stock data:                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2000-01-03  59.031250  59.125000  53.437500  55.500000  35.440235  1199600
# 2000-01-04  54.625000  55.000000  52.500000  52.812500  33.724098   816100
# 2000-01-05  52.750000  53.250000  51.062500  52.750000  33.684181  1124700
# 2000-01-06  52.750000  54.937500  52.375000  53.500000  34.163124  1112100
# 2000-01-07  53.750000  54.250000  53.312500  53.625000  34.242935   782000
# ...               ...        ...        ...        ...        ...      ...
# 2024-06-24  41.500000  42.919998  41.259998  42.450001  42.450001  1328400
# 2024-06-25  42.240002  42.509998  41.450001  41.990002  41.990002  1795600
# 2024-06-26  41.680000  41.880001  41.430000  41.849998  41.849998   778800
# 2024-06-27  41.830002  42.119999  41.410000  42.060001  42.060001   875500
# 2024-06-28  42.560001  43.470001  42.279999  43.369999  43.369999  1867800
#
# [6161 rows x 6 columns]
# 2024-06-29 15:28:28,418, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-06-29 15:28:28,418, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-06-29 15:28:29,310, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-06-29 15:28:29,310, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-06-29 15:28:29,311, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-06-29
# 2024-06-29 15:28:29,311, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-06-29
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-29 15:28:29,448, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-02-01   31.500000   31.740000   30.469999   31.010000   28.544941
# 2013-02-04   31.090000   31.990000   30.760000   31.020000   28.554142
# 2013-02-05   31.250000   31.980000   30.850000   31.040001   28.572556
# 2013-02-06   30.980000   31.430000   30.750000   31.030001   28.563353
# 2013-02-07   31.000000   32.730000   31.000000   32.000000   29.456244
# ...                ...         ...         ...         ...         ...
# 2024-06-24  171.710007  174.289993  170.300003  171.839996  171.839996
# 2024-06-25  171.789993  172.419998  167.720001  167.979996  167.979996
# 2024-06-26  167.210007  171.509995  166.449997  170.899994  170.899994
# 2024-06-27  174.490005  181.660004  174.259995  176.460007  176.460007
# 2024-06-28  176.460007  177.070007  173.029999  173.360001  173.360001
#
#               Volume
# Date
# 2013-02-01  66789100
# 2013-02-04   7695400
# 2013-02-05   5013200
# 2013-02-06   2126100
# 2013-02-07   3800800
# ...              ...
# 2024-06-24   1885900
# 2024-06-25   2293400
# 2024-06-26   2053800
# 2024-06-27   4164700
# 2024-06-28   4188600
#
# [2871 rows x 6 columns]
# 2024-06-29 15:28:29,448, data_manager.py, 110, INFO, stock data:                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-02-01   31.500000   31.740000   30.469999   31.010000   28.544941
# 2013-02-04   31.090000   31.990000   30.760000   31.020000   28.554142
# 2013-02-05   31.250000   31.980000   30.850000   31.040001   28.572556
# 2013-02-06   30.980000   31.430000   30.750000   31.030001   28.563353
# 2013-02-07   31.000000   32.730000   31.000000   32.000000   29.456244
# ...                ...         ...         ...         ...         ...
# 2024-06-24  171.710007  174.289993  170.300003  171.839996  171.839996
# 2024-06-25  171.789993  172.419998  167.720001  167.979996  167.979996
# 2024-06-26  167.210007  171.509995  166.449997  170.899994  170.899994
# 2024-06-27  174.490005  181.660004  174.259995  176.460007  176.460007
# 2024-06-28  176.460007  177.070007  173.029999  173.360001  173.360001
#
#               Volume
# Date
# 2013-02-01  66789100
# 2013-02-04   7695400
# 2013-02-05   5013200
# 2013-02-06   2126100
# 2013-02-07   3800800
# ...              ...
# 2024-06-24   1885900
# 2024-06-25   2293400
# 2024-06-26   2053800
# 2024-06-27   4164700
# 2024-06-28   4188600
#
# [2871 rows x 6 columns]
# 2024-06-29 15:28:29,449, data_manager.py, 82, INFO, Saving data for ZTS by year
# 2024-06-29 15:28:29,449, data_manager.py, 82, INFO, Saving data for ZTS by year

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-06-29 15:28:29,832, data_manager.py, 118, INFO, Creating features data.
# 2024-06-29 15:28:29,832, data_manager.py, 118, INFO, Creating features data.
# 2024-06-29 15:28:29,834, data_manager.py, 129, INFO, Loading price data from ../../05_src/data/prices/
# 2024-06-29 15:28:29,834, data_manager.py, 129, INFO, Loading price data from ../../05_src/data/prices/
# /home/stumac/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/dataframe/core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-06-29 15:28:30,311, data_manager.py, 137, INFO, Creating features
# 2024-06-29 15:28:30,311, data_manager.py, 137, INFO, Creating features
# /home/stumac/code/uoft_dsi/scaling_to_production/01_materials/labs/../../05_src/data_manager.py:139: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-06-29 15:28:30,354, data_manager.py, 155, INFO, Creating target
# 2024-06-29 15:28:30,354, data_manager.py, 155, INFO, Creating target
# /home/stumac/code/uoft_dsi/scaling_to_production/01_materials/labs/../../05_src/data_manager.py:156: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-06-29 15:28:30,473, data_manager.py, 165, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-06-29 15:28:30,473, data_manager.py, 165, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
